# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style = 'whitegrid')
import os

from sklearn.preprocessing        import LabelEncoder, StandardScaler
from sklearn.model_selection      import train_test_split, StratifiedKFold
from sklearn.linear_model         import LinearRegression
from sklearn.tree                 import DecisionTreeRegressor
from sklearn.ensemble             import RandomForestRegressor, AdaBoostRegressor, BaggingRegressor, ExtraTreesRegressor
from lightgbm                     import LGBMRegressor
from xgboost                      import XGBRegressor
from catboost                     import CatBoostRegressor
from sklearn.metrics              import mean_squared_error

le = LabelEncoder()

path = os.getcwd()
data_path = 'C:\\Users\\sunil\\Projects\\HackerEarth\\7342422066d511eb\\dataset\\'

# %%
train = pd.read_csv(data_path + 'cleaned_train.csv')
test = pd.read_csv(data_path + 'cleaned_test.csv')
sample_sub = pd.read_csv(data_path + 'sample_submission.csv')

# %%
sample_sub = test[['Customer Id', 'Artist Name']].copy()
sample_sub['Cost'] = None
sample_sub = sample_sub.drop('Artist Name', axis = 1)

# %%
train['Cost'] = train['Cost'].abs()

# %%
train['Cost'] = np.log(train['Cost'])

# %%
# metrics = 100*max(0, 1-metrics.mean_squared_log_error(actual, predicted))

# %% [markdown]
# ---
# # Data Preprocessing

# %%
df = pd.concat([train, test], axis = 0).reset_index(drop=True)

# %%
ID = 'Customer Id'
name = 'Artist Name'
date_1 = 'Scheduled Date'
date_2 = 'Delivery Date'
location = 'Customer Location'
target = 'Cost'


cat_cols = ['Material','International', 'Express Shipment', 
            'Installation Included','Transport',
            'Fragile', 'Customer Information', 
            'Remote Location']

num_cols = ['Artist Reputation', 'Height', 'Width','Weight',
            'Price Of Sculpture', 'Base Shipping Price']

# %%
df[cat_cols] = df[cat_cols].apply(le.fit_transform)

#df = pd.get_dummies(data = df, columns=cat_cols, drop_first=True)

# %%
features = [col for col in df.columns if col not in ([ID, name, date_1, date_2, location, target])]

# %% [markdown]
# ## Splitting

# %%
train_proc, test_proc = df[:train.shape[0]], df[train.shape[0]:].reset_index(drop = True)

# %%
trn, val = train_test_split(train_proc, test_size = 0.2, random_state = 1999)

##### Input for model
X_trn, X_val = trn[features], val[features]

##### Target column
y_trn, y_val = trn[target], val[target]

##### Features for test data that we will be predicting
X_test = test_proc[features]

# %%
model_dict = {}

model_dict['Linear Regression'] = LinearRegression()
model_dict['Decision Tree'] = DecisionTreeRegressor(random_state = 1)
model_dict['Extra Trees'] = ExtraTreesRegressor(random_state = 1)
model_dict['Random Forest'] = RandomForestRegressor(random_state = 1)
model_dict['AdaBoost'] = AdaBoostRegressor(random_state = 1)
model_dict['Bagging'] = BaggingRegressor(random_state = 1)
model_dict['XGBoost'] = XGBRegressor(random_state = 1)
model_dict['LGBM'] = LGBMRegressor(random_state = 1)
model_dict['Cat'] = CatBoostRegressor(verbose=False, random_state =1)

# %%
def model_test(X_train, X_test, y_train, y_test,model,model_name):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    y_pred = np.abs(y_pred)
    accuracy = 100*max(0, 1-mean_squared_error(y_test, y_pred))
    print('======================================{}======================================='.format(model_name))
    print('Score is : {}'.format(accuracy))
    print()

# %%
for model_name,model in model_dict.items():
    model_test(X_trn, X_val, y_trn, y_val, model, model_name)
# Out:
# ======================================Linear Regression=======================================
# Score is : 11.26568677279045
#
# ======================================Decision Tree=======================================
# Score is : 75.90201628557229
#
# ======================================Extra Trees=======================================
# Score is : 86.26725578388523
#
# ======================================Random Forest=======================================
# Score is : 86.79595133509662
#
# ======================================AdaBoost=======================================
# Score is : 61.10259301986842
#
# ======================================Bagging=======================================
# Score is : 85.51298974979582
#
# ======================================XGBoost=======================================
# Score is : 88.75772463429364
#
# ======================================LGBM=======================================
# Score is : 88.49146427453147
#
# ======================================Cat=======================================
# Score is : 90.99679816552691

# %%
lgb_params = {'max_depth': 4, 'n_estimators': 976, 'learning_rate': 0.08133551909202762, 'num_leaves': 318}

# %%
cat = CatBoostRegressor(random_state = 1)

_ = cat.fit(train_proc[features], train_proc[target])

preds = cat.predict(test_proc[features])
preds = np.exp(preds)
# Out:
# Learning rate set to 0.054463
# 0:	learn: 1.5780695	total: 2.95ms	remaining: 2.95s
# 1:	learn: 1.5071660	total: 6.2ms	remaining: 3.09s
# 2:	learn: 1.4397906	total: 15.5ms	remaining: 5.17s
# 3:	learn: 1.3777426	total: 18.3ms	remaining: 4.57s
# 4:	learn: 1.3208123	total: 21.1ms	remaining: 4.21s
# 5:	learn: 1.2650310	total: 23.7ms	remaining: 3.93s
# 6:	learn: 1.2145778	total: 27.5ms	remaining: 3.9s
# 7:	learn: 1.1639484	total: 30.9ms	remaining: 3.83s
# 8:	learn: 1.1178391	total: 33.4ms	remaining: 3.68s
# 9:	learn: 1.0747251	total: 39.5ms	remaining: 3.91s
# 10:	learn: 1.0318696	total: 42.1ms	remaining: 3.79s
# 11:	learn: 0.9938101	total: 45.2ms	remaining: 3.72s
# 12:	learn: 0.9571971	total: 47.8ms	remaining: 3.63s
# 13:	learn: 0.9220534	total: 52.3ms	remaining: 3.68s
# 14:	learn: 0.8891652	total: 55.2ms	remaining: 3.62s
# 15:	learn: 0.8574355	total: 57.8ms	remaining: 3.55s
# 16:	learn: 0.8282047	total: 60.8ms	remaining: 3.52s
# 17:	learn: 0.8008061	total: 63.3ms	remaining: 3.46s
# 18:	learn: 0.7749391	total: 65.9ms	remaining: 3.4s
# 19:	learn: 0.7506054	total: 68.4ms	remaining: 3.35s
# 20:	learn: 0.7287287	total: 72.2ms	remaining: 3.37s
# 21:	learn: 0.7072478	total: 74.7ms	remaining: 3.32s
# 22:	learn: 0.6871758	total: 77.3ms	remaining: 3.28s
# 23:	learn: 0.6693405	total: 79.8ms	remaining: 3.24s
# 24:	learn: 0.6516239	total: 82.4ms	remaining: 3.21s
# 25:	learn: 0.6342957	total: 85ms	remaining: 3.19s
# 26:	learn: 0.6184634	total: 87.6ms	remaining: 3.16s
# 27:	learn: 0.6036467	total: 90.3ms	remaining: 3.13s
# 28:	learn: 0.5899377	total: 92.9ms	remaining: 3.11s
# 29:	learn: 0.5774625	total: 95.4ms	remaining: 3.09s
# 30:	learn: 0.5655475	total: 98ms	remaining: 3.06s
# 31:	learn: 0.5540486	total: 100ms	remaining: 3.04s
# 32:	learn: 0.5432456	total: 103ms	remaining: 3.02s
# 33:	learn: 0.5332485	total: 105ms	remaining: 3s
# 34:	learn: 0.5238292	total: 110ms	remaining: 3.02s
# 35:	learn: 0.5160022	total: 112ms	remaining: 3s
# 36:	learn: 0.5075076	total: 115ms	remaining: 2.98s
# 37:	learn: 0.4996974	total: 118ms	remaining: 2.99s
# 38:	learn: 0.4925049	total: 121ms	remaining: 2.98s
# 39:	learn: 0.4853802	total: 123ms	remaining: 2.96s
# 40:	learn: 0.4786190	total: 128ms	remaining: 2.98s
# 41:	learn: 0.4726845	total: 130ms	remaining: 2.97s
# 42:	learn: 0.4670139	total: 134ms	remaining: 2.99s
# 43:	learn: 0.4616225	total: 137ms	remaining: 2.97s
# 44:	learn: 0.4567723	total: 139ms	remaining: 2.96s
# 45:	learn: 0.4521447	total: 142ms	remaining: 2.94s
# 46:	learn: 0.4476242	total: 146ms	remaining: 2.96s
# 47:	learn: 0.4439088	total: 149ms	remaining: 2.95s
# 48:	learn: 0.4400928	total: 151ms	remaining: 2.94s
# 49:	learn: 0.4367031	total: 154ms	remaining: 2.93s
# 50:	learn: 0.4330730	total: 157ms	remaining: 2.93s
# 51:	learn: 0.4299068	total: 160ms	remaining: 2.92s
# 52:	learn: 0.4267942	total: 166ms	remaining: 2.96s
# 53:	learn: 0.4239325	total: 169ms	remaining: 2.95s
# 54:	learn: 0.4213614	total: 173ms	remaining: 2.97s
# 55:	learn: 0.4190945	total: 176ms	remaining: 2.96s
# 56:	learn: 0.4166534	total: 178ms	remaining: 2.95s
# 57:	learn: 0.4143267	total: 181ms	remaining: 2.94s
# 58:	learn: 0.4123755	total: 184ms	remaining: 2.93s
# 59:	learn: 0.4104521	total: 187ms	remaining: 2.92s
# 60:	learn: 0.4080223	total: 192ms	remaining: 2.95s
# 61:	learn: 0.4060512	total: 194ms	remaining: 2.94s
# 62:	learn: 0.4041749	total: 197ms	remaining: 2.93s
# 63:	learn: 0.4021884	total: 199ms	remaining: 2.91s
# 64:	learn: 0.4005233	total: 202ms	remaining: 2.91s
# 65:	learn: 0.3981692	total: 205ms	remaining: 2.9s
# 66:	learn: 0.3967137	total: 207ms	remaining: 2.88s
# 67:	learn: 0.3952823	total: 213ms	remaining: 2.92s
# 68:	learn: 0.3940498	total: 216ms	remaining: 2.92s
# 69:	learn: 0.3927345	total: 219ms	remaining: 2.9s
# 70:	learn: 0.3915497	total: 221ms	remaining: 2.89s
# 71:	learn: 0.3888156	total: 224ms	remaining: 2.88s
# 72:	learn: 0.3875656	total: 226ms	remaining: 2.87s
# 73:	learn: 0.3862765	total: 229ms	remaining: 2.86s
# 74:	learn: 0.3852701	total: 231ms	remaining: 2.85s
# 75:	learn: 0.3843180	total: 236ms	remaining: 2.87s
# 76:	learn: 0.3831822	total: 238ms	remaining: 2.86s
# 77:	learn: 0.3810836	total: 241ms	remaining: 2.85s
# 78:	learn: 0.3800842	total: 243ms	remaining: 2.84s
# 79:	learn: 0.3783598	total: 246ms	remaining: 2.83s
# 80:	learn: 0.3769857	total: 250ms	remaining: 2.83s
# 81:	learn: 0.3760372	total: 252ms	remaining: 2.82s
# 82:	learn: 0.3751125	total: 256ms	remaining: 2.83s
# 83:	learn: 0.3741633	total: 259ms	remaining: 2.82s
# 84:	learn: 0.3732690	total: 261ms	remaining: 2.81s
# 85:	learn: 0.3725012	total: 264ms	remaining: 2.8s
# 86:	learn: 0.3718929	total: 266ms	remaining: 2.79s
# 87:	learn: 0.3696364	total: 269ms	remaining: 2.78s
# 88:	learn: 0.3687341	total: 271ms	remaining: 2.77s
# 89:	learn: 0.3681501	total: 273ms	remaining: 2.76s
# 90:	learn: 0.3672889	total: 276ms	remaining: 2.75s
# 91:	learn: 0.3663935	total: 278ms	remaining: 2.74s
# 92:	learn: 0.3658599	total: 280ms	remaining: 2.73s
# 93:	learn: 0.3650154	total: 283ms	remaining: 2.73s
# 94:	learn: 0.3643652	total: 285ms	remaining: 2.72s
# 95:	learn: 0.3633164	total: 288ms	remaining: 2.71s
# 96:	learn: 0.3627338	total: 290ms	remaining: 2.7s
# 97:	learn: 0.3621725	total: 292ms	remaining: 2.69s
# 98:	learn: 0.3607305	total: 295ms	remaining: 2.68s
# 99:	learn: 0.3598243	total: 297ms	remaining: 2.67s
# 100:	learn: 0.3592117	total: 300ms	remaining: 2.67s
# 101:	learn: 0.3586047	total: 304ms	remaining: 2.68s
# 102:	learn: 0.3577740	total: 308ms	remaining: 2.68s
# 103:	learn: 0.3571167	total: 310ms	remaining: 2.67s
# 104:	learn: 0.3555976	total: 313ms	remaining: 2.66s
# 105:	learn: 0.3549304	total: 315ms	remaining: 2.66s
# 106:	learn: 0.3539296	total: 318ms	remaining: 2.65s
# 107:	learn: 0.3531709	total: 320ms	remaining: 2.64s
# 108:	learn: 0.3524619	total: 323ms	remaining: 2.64s
# 109:	learn: 0.3516698	total: 326ms	remaining: 2.63s
# 110:	learn: 0.3512841	total: 328ms	remaining: 2.63s
# 111:	learn: 0.3509109	total: 331ms	remaining: 2.62s
# 112:	learn: 0.3501555	total: 334ms	remaining: 2.62s
# 113:	learn: 0.3496661	total: 337ms	remaining: 2.62s
# 114:	learn: 0.3492003	total: 339ms	remaining: 2.61s
# 115:	learn: 0.3478992	total: 342ms	remaining: 2.61s
# 116:	learn: 0.3475190	total: 344ms	remaining: 2.6s
# 117:	learn: 0.3466176	total: 347ms	remaining: 2.59s
# 118:	learn: 0.3462065	total: 349ms	remaining: 2.58s
# 119:	learn: 0.3454645	total: 352ms	remaining: 2.58s
# 120:	learn: 0.3447057	total: 355ms	remaining: 2.58s
# 121:	learn: 0.3439220	total: 357ms	remaining: 2.57s
# 122:	learn: 0.3432518	total: 360ms	remaining: 2.57s
# 123:	learn: 0.3428244	total: 362ms	remaining: 2.56s
# 124:	learn: 0.3424463	total: 365ms	remaining: 2.56s
# 125:	learn: 0.3414698	total: 368ms	remaining: 2.55s
# 126:	learn: 0.3403423	total: 370ms	remaining: 2.54s
# 127:	learn: 0.3394216	total: 373ms	remaining: 2.54s
# 128:	learn: 0.3385531	total: 376ms	remaining: 2.54s
# 129:	learn: 0.3380729	total: 378ms	remaining: 2.53s
# 130:	learn: 0.3370615	total: 385ms	remaining: 2.56s
# 131:	learn: 0.3367380	total: 392ms	remaining: 2.58s
# 132:	learn: 0.3359094	total: 394ms	remaining: 2.57s
# 133:	learn: 0.3354308	total: 397ms	remaining: 2.56s
# 134:	learn: 0.3346408	total: 399ms	remaining: 2.56s
# 135:	learn: 0.3341234	total: 402ms	remaining: 2.55s
# 136:	learn: 0.3328204	total: 404ms	remaining: 2.55s
# 137:	learn: 0.3320898	total: 407ms	remaining: 2.54s
# 138:	learn: 0.3317574	total: 409ms	remaining: 2.53s
# 139:	learn: 0.3311714	total: 411ms	remaining: 2.53s
# 140:	learn: 0.3307154	total: 414ms	remaining: 2.52s
# 141:	learn: 0.3298622	total: 416ms	remaining: 2.52s
# 142:	learn: 0.3295647	total: 419ms	remaining: 2.51s
# 143:	learn: 0.3284673	total: 422ms	remaining: 2.51s
# 144:	learn: 0.3278655	total: 425ms	remaining: 2.5s
# 145:	learn: 0.3275196	total: 427ms	remaining: 2.5s
# 146:	learn: 0.3268936	total: 430ms	remaining: 2.49s
# 147:	learn: 0.3259403	total: 432ms	remaining: 2.49s
# 148:	learn: 0.3253987	total: 434ms	remaining: 2.48s
# 149:	learn: 0.3248238	total: 437ms	remaining: 2.48s
# 150:	learn: 0.3239258	total: 439ms	remaining: 2.47s
# 151:	learn: 0.3231026	total: 442ms	remaining: 2.46s
# 152:	learn: 0.3220655	total: 444ms	remaining: 2.46s
# 153:	learn: 0.3214042	total: 447ms	remaining: 2.45s
# 154:	learn: 0.3204250	total: 451ms	remaining: 2.46s
# 155:	learn: 0.3197574	total: 453ms	remaining: 2.45s
# 156:	learn: 0.3188711	total: 455ms	remaining: 2.44s
# 157:	learn: 0.3182869	total: 458ms	remaining: 2.44s
# 158:	learn: 0.3175468	total: 462ms	remaining: 2.44s
# 159:	learn: 0.3170174	total: 465ms	remaining: 2.44s
# 160:	learn: 0.3160826	total: 467ms	remaining: 2.43s
# 161:	learn: 0.3149421	total: 470ms	remaining: 2.43s
# 162:	learn: 0.3139065	total: 472ms	remaining: 2.42s
# 163:	learn: 0.3127684	total: 474ms	remaining: 2.42s
# 164:	learn: 0.3116237	total: 477ms	remaining: 2.41s
# 165:	learn: 0.3110798	total: 481ms	remaining: 2.41s
# 166:	learn: 0.3101367	total: 483ms	remaining: 2.41s
# 167:	learn: 0.3095092	total: 485ms	remaining: 2.4s
# 168:	learn: 0.3089047	total: 488ms	remaining: 2.4s
# 169:	learn: 0.3081768	total: 491ms	remaining: 2.4s
# 170:	learn: 0.3075049	total: 493ms	remaining: 2.39s
# 171:	learn: 0.3066833	total: 496ms	remaining: 2.39s
# 172:	learn: 0.3060934	total: 498ms	remaining: 2.38s
# 173:	learn: 0.3054830	total: 501ms	remaining: 2.38s
# 174:	learn: 0.3048513	total: 505ms	remaining: 2.38s
# 175:	learn: 0.3044876	total: 507ms	remaining: 2.37s
# 176:	learn: 0.3039137	total: 510ms	remaining: 2.37s
# 177:	learn: 0.3033649	total: 512ms	remaining: 2.37s
# 178:	learn: 0.3022083	total: 515ms	remaining: 2.36s
# 179:	learn: 0.3018377	total: 517ms	remaining: 2.35s
# 180:	learn: 0.3012520	total: 520ms	remaining: 2.35s
# 181:	learn: 0.3007993	total: 522ms	remaining: 2.35s
# 182:	learn: 0.2998506	total: 525ms	remaining: 2.35s
# 183:	learn: 0.2992428	total: 528ms	remaining: 2.34s
# 184:	learn: 0.2983971	total: 530ms	remaining: 2.34s
# 185:	learn: 0.2981449	total: 533ms	remaining: 2.33s
# 186:	learn: 0.2974273	total: 535ms	remaining: 2.33s
# 187:	learn: 0.2969872	total: 538ms	remaining: 2.32s
# 188:	learn: 0.2964105	total: 540ms	remaining: 2.32s
# 189:	learn: 0.2959057	total: 544ms	remaining: 2.32s
# 190:	learn: 0.2950988	total: 547ms	remaining: 2.32s
# 191:	learn: 0.2942045	total: 549ms	remaining: 2.31s
# 192:	learn: 0.2937710	total: 552ms	remaining: 2.31s
# 193:	learn: 0.2933162	total: 554ms	remaining: 2.3s
# 194:	learn: 0.2929757	total: 557ms	remaining: 2.3s
# 195:	learn: 0.2922893	total: 559ms	remaining: 2.29s
# 196:	learn: 0.2917404	total: 562ms	remaining: 2.29s
# 197:	learn: 0.2914721	total: 564ms	remaining: 2.29s
# 198:	learn: 0.2910831	total: 567ms	remaining: 2.28s
# 199:	learn: 0.2900604	total: 569ms	remaining: 2.27s
# 200:	learn: 0.2896267	total: 571ms	remaining: 2.27s
# 201:	learn: 0.2891684	total: 574ms	remaining: 2.27s
# 202:	learn: 0.2885664	total: 577ms	remaining: 2.26s
# 203:	learn: 0.2879210	total: 579ms	remaining: 2.26s
# 204:	learn: 0.2874935	total: 582ms	remaining: 2.26s
# 205:	learn: 0.2867061	total: 584ms	remaining: 2.25s
# 206:	learn: 0.2859704	total: 587ms	remaining: 2.25s
# 207:	learn: 0.2852547	total: 589ms	remaining: 2.24s
# 208:	learn: 0.2848510	total: 593ms	remaining: 2.24s
# 209:	learn: 0.2843141	total: 597ms	remaining: 2.24s
# 210:	learn: 0.2840716	total: 600ms	remaining: 2.24s
# 211:	learn: 0.2837920	total: 602ms	remaining: 2.24s
# 212:	learn: 0.2834365	total: 605ms	remaining: 2.24s
# 213:	learn: 0.2826368	total: 608ms	remaining: 2.23s
# 214:	learn: 0.2820467	total: 610ms	remaining: 2.23s
# 215:	learn: 0.2817774	total: 613ms	remaining: 2.22s
# 216:	learn: 0.2815437	total: 616ms	remaining: 2.22s
# 217:	learn: 0.2809616	total: 618ms	remaining: 2.22s
# 218:	learn: 0.2804883	total: 621ms	remaining: 2.21s
# 219:	learn: 0.2801140	total: 623ms	remaining: 2.21s
# 220:	learn: 0.2797165	total: 626ms	remaining: 2.21s
# 221:	learn: 0.2792257	total: 629ms	remaining: 2.2s
# 222:	learn: 0.2787418	total: 631ms	remaining: 2.2s
# 223:	learn: 0.2784803	total: 634ms	remaining: 2.19s
# 224:	learn: 0.2779139	total: 637ms	remaining: 2.19s
# 225:	learn: 0.2776740	total: 639ms	remaining: 2.19s
# 226:	learn: 0.2772686	total: 642ms	remaining: 2.18s
# 227:	learn: 0.2769772	total: 644ms	remaining: 2.18s
# 228:	learn: 0.2767057	total: 647ms	remaining: 2.18s
# 229:	learn: 0.2759514	total: 650ms	remaining: 2.18s
# 230:	learn: 0.2757475	total: 653ms	remaining: 2.17s
# 231:	learn: 0.2752379	total: 655ms	remaining: 2.17s
# 232:	learn: 0.2747887	total: 658ms	remaining: 2.17s
# 233:	learn: 0.2744247	total: 661ms	remaining: 2.16s
# 234:	learn: 0.2739519	total: 664ms	remaining: 2.16s
# 235:	learn: 0.2732788	total: 667ms	remaining: 2.16s
# 236:	learn: 0.2730788	total: 669ms	remaining: 2.15s
# 237:	learn: 0.2724308	total: 672ms	remaining: 2.15s
# 238:	learn: 0.2721378	total: 676ms	remaining: 2.15s
# 239:	learn: 0.2715194	total: 679ms	remaining: 2.15s
# 240:	learn: 0.2711237	total: 682ms	remaining: 2.15s
# 241:	learn: 0.2706747	total: 685ms	remaining: 2.15s
# 242:	learn: 0.2699323	total: 687ms	remaining: 2.14s
# 243:	learn: 0.2695978	total: 690ms	remaining: 2.14s
# 244:	learn: 0.2693151	total: 693ms	remaining: 2.13s
# 245:	learn: 0.2688393	total: 696ms	remaining: 2.13s
# 246:	learn: 0.2685826	total: 699ms	remaining: 2.13s
# 247:	learn: 0.2683052	total: 702ms	remaining: 2.13s
# 248:	learn: 0.2678119	total: 705ms	remaining: 2.12s
# 249:	learn: 0.2674103	total: 707ms	remaining: 2.12s
# 250:	learn: 0.2670475	total: 710ms	remaining: 2.12s
# 251:	learn: 0.2664727	total: 713ms	remaining: 2.12s
# 252:	learn: 0.2662503	total: 716ms	remaining: 2.11s
# 253:	learn: 0.2657364	total: 719ms	remaining: 2.11s
# 254:	learn: 0.2654848	total: 722ms	remaining: 2.11s
# 255:	learn: 0.2651288	total: 725ms	remaining: 2.11s
# 256:	learn: 0.2648079	total: 730ms	remaining: 2.11s
# 257:	learn: 0.2643449	total: 733ms	remaining: 2.11s
# 258:	learn: 0.2640423	total: 736ms	remaining: 2.11s
# 259:	learn: 0.2635895	total: 741ms	remaining: 2.11s
# 260:	learn: 0.2634477	total: 743ms	remaining: 2.1s
# 261:	learn: 0.2632062	total: 746ms	remaining: 2.1s
# 262:	learn: 0.2629913	total: 749ms	remaining: 2.1s
# 263:	learn: 0.2627388	total: 752ms	remaining: 2.1s
# 264:	learn: 0.2625370	total: 755ms	remaining: 2.09s
# 265:	learn: 0.2624167	total: 758ms	remaining: 2.09s
# 266:	learn: 0.2620454	total: 761ms	remaining: 2.09s
# 267:	learn: 0.2617711	total: 764ms	remaining: 2.09s
# 268:	learn: 0.2615135	total: 767ms	remaining: 2.08s
# 269:	learn: 0.2613153	total: 769ms	remaining: 2.08s
# 270:	learn: 0.2610410	total: 772ms	remaining: 2.08s
# 271:	learn: 0.2608470	total: 775ms	remaining: 2.07s
# 272:	learn: 0.2606726	total: 777ms	remaining: 2.07s
# 273:	learn: 0.2604165	total: 780ms	remaining: 2.07s
# 274:	learn: 0.2601425	total: 782ms	remaining: 2.06s
# 275:	learn: 0.2599356	total: 786ms	remaining: 2.06s
# 276:	learn: 0.2595839	total: 789ms	remaining: 2.06s
# 277:	learn: 0.2593222	total: 791ms	remaining: 2.05s
# 278:	learn: 0.2590937	total: 795ms	remaining: 2.05s
# 279:	learn: 0.2588785	total: 797ms	remaining: 2.05s
# 280:	learn: 0.2585531	total: 799ms	remaining: 2.04s
# 281:	learn: 0.2583792	total: 802ms	remaining: 2.04s
# 282:	learn: 0.2580731	total: 804ms	remaining: 2.04s
# 283:	learn: 0.2576561	total: 807ms	remaining: 2.03s
# 284:	learn: 0.2574212	total: 809ms	remaining: 2.03s
# 285:	learn: 0.2572546	total: 812ms	remaining: 2.03s
# 286:	learn: 0.2571062	total: 814ms	remaining: 2.02s
# 287:	learn: 0.2567290	total: 817ms	remaining: 2.02s
# 288:	learn: 0.2561463	total: 819ms	remaining: 2.02s
# 289:	learn: 0.2560539	total: 822ms	remaining: 2.01s
# 290:	learn: 0.2557556	total: 824ms	remaining: 2.01s
# 291:	learn: 0.2554799	total: 828ms	remaining: 2.01s
# 292:	learn: 0.2551927	total: 832ms	remaining: 2.01s
# 293:	learn: 0.2549115	total: 835ms	remaining: 2s
# 294:	learn: 0.2546300	total: 837ms	remaining: 2s
# 295:	learn: 0.2544759	total: 840ms	remaining: 2s
# 296:	learn: 0.2542036	total: 842ms	remaining: 1.99s
# 297:	learn: 0.2539870	total: 846ms	remaining: 1.99s
# 298:	learn: 0.2538121	total: 848ms	remaining: 1.99s
# 299:	learn: 0.2535769	total: 851ms	remaining: 1.99s
# 300:	learn: 0.2531306	total: 853ms	remaining: 1.98s
# 301:	learn: 0.2528870	total: 856ms	remaining: 1.98s
# 302:	learn: 0.2525523	total: 860ms	remaining: 1.98s
# 303:	learn: 0.2521918	total: 863ms	remaining: 1.98s
# 304:	learn: 0.2520204	total: 865ms	remaining: 1.97s
# 305:	learn: 0.2515264	total: 868ms	remaining: 1.97s
# 306:	learn: 0.2512591	total: 870ms	remaining: 1.96s
# 307:	learn: 0.2511672	total: 873ms	remaining: 1.96s
# 308:	learn: 0.2509462	total: 876ms	remaining: 1.96s
# 309:	learn: 0.2506972	total: 878ms	remaining: 1.95s
# 310:	learn: 0.2503173	total: 881ms	remaining: 1.95s
# 311:	learn: 0.2501785	total: 885ms	remaining: 1.95s
# 312:	learn: 0.2499038	total: 887ms	remaining: 1.95s
# 313:	learn: 0.2495637	total: 889ms	remaining: 1.94s
# 314:	learn: 0.2494402	total: 892ms	remaining: 1.94s
# 315:	learn: 0.2491441	total: 894ms	remaining: 1.94s
# 316:	learn: 0.2489289	total: 897ms	remaining: 1.93s
# 317:	learn: 0.2488175	total: 899ms	remaining: 1.93s
# 318:	learn: 0.2486627	total: 901ms	remaining: 1.92s
# 319:	learn: 0.2483364	total: 904ms	remaining: 1.92s
# 320:	learn: 0.2481693	total: 906ms	remaining: 1.92s
# 321:	learn: 0.2477751	total: 909ms	remaining: 1.91s
# 322:	learn: 0.2475523	total: 911ms	remaining: 1.91s
# 323:	learn: 0.2472516	total: 914ms	remaining: 1.91s
# 324:	learn: 0.2470039	total: 916ms	remaining: 1.9s
# 325:	learn: 0.2468116	total: 919ms	remaining: 1.9s
# 326:	learn: 0.2466681	total: 923ms	remaining: 1.9s
# 327:	learn: 0.2462726	total: 925ms	remaining: 1.9s
# 328:	learn: 0.2461437	total: 928ms	remaining: 1.89s
# 329:	learn: 0.2459351	total: 930ms	remaining: 1.89s
# 330:	learn: 0.2457203	total: 933ms	remaining: 1.89s
# 331:	learn: 0.2456242	total: 935ms	remaining: 1.88s
# 332:	learn: 0.2455070	total: 938ms	remaining: 1.88s
# 333:	learn: 0.2452942	total: 940ms	remaining: 1.87s
# 334:	learn: 0.2450736	total: 943ms	remaining: 1.87s
# 335:	learn: 0.2448389	total: 945ms	remaining: 1.87s
# 336:	learn: 0.2445703	total: 948ms	remaining: 1.86s
# 337:	learn: 0.2441155	total: 950ms	remaining: 1.86s
# 338:	learn: 0.2439294	total: 953ms	remaining: 1.86s
# 339:	learn: 0.2436084	total: 955ms	remaining: 1.85s
# 340:	learn: 0.2434159	total: 957ms	remaining: 1.85s
# 341:	learn: 0.2432488	total: 960ms	remaining: 1.85s
# 342:	learn: 0.2431066	total: 962ms	remaining: 1.84s
# 343:	learn: 0.2430095	total: 965ms	remaining: 1.84s
# 344:	learn: 0.2428127	total: 967ms	remaining: 1.84s
# 345:	learn: 0.2427020	total: 973ms	remaining: 1.84s
# 346:	learn: 0.2425382	total: 975ms	remaining: 1.83s
# 347:	learn: 0.2423069	total: 978ms	remaining: 1.83s
# 348:	learn: 0.2421204	total: 980ms	remaining: 1.83s
# 349:	learn: 0.2419673	total: 985ms	remaining: 1.83s
# 350:	learn: 0.2418027	total: 987ms	remaining: 1.82s
# 351:	learn: 0.2414684	total: 990ms	remaining: 1.82s
# 352:	learn: 0.2412888	total: 992ms	remaining: 1.82s
# 353:	learn: 0.2411478	total: 994ms	remaining: 1.81s
# 354:	learn: 0.2410224	total: 997ms	remaining: 1.81s
# 355:	learn: 0.2408421	total: 999ms	remaining: 1.81s
# 356:	learn: 0.2406577	total: 1s	remaining: 1.8s
# 357:	learn: 0.2403655	total: 1s	remaining: 1.8s
# 358:	learn: 0.2401891	total: 1.01s	remaining: 1.8s
# 359:	learn: 0.2401001	total: 1.01s	remaining: 1.79s
# 360:	learn: 0.2398590	total: 1.01s	remaining: 1.79s
# 361:	learn: 0.2396947	total: 1.01s	remaining: 1.79s
# 362:	learn: 0.2396179	total: 1.02s	remaining: 1.79s
# 363:	learn: 0.2394435	total: 1.02s	remaining: 1.78s
# 364:	learn: 0.2393742	total: 1.02s	remaining: 1.78s
# 365:	learn: 0.2391674	total: 1.03s	remaining: 1.78s
# 366:	learn: 0.2389104	total: 1.03s	remaining: 1.78s
# 367:	learn: 0.2387404	total: 1.03s	remaining: 1.77s
# 368:	learn: 0.2385003	total: 1.03s	remaining: 1.77s
# 369:	learn: 0.2384259	total: 1.04s	remaining: 1.77s
# 370:	learn: 0.2382708	total: 1.04s	remaining: 1.76s
# 371:	learn: 0.2381517	total: 1.04s	remaining: 1.76s
# 372:	learn: 0.2380504	total: 1.05s	remaining: 1.76s
# 373:	learn: 0.2379306	total: 1.05s	remaining: 1.75s
# 374:	learn: 0.2378658	total: 1.05s	remaining: 1.75s
# 375:	learn: 0.2377114	total: 1.05s	remaining: 1.75s
# 376:	learn: 0.2374810	total: 1.05s	remaining: 1.74s
# 377:	learn: 0.2371842	total: 1.06s	remaining: 1.74s
# 378:	learn: 0.2369944	total: 1.06s	remaining: 1.74s
# 379:	learn: 0.2368306	total: 1.06s	remaining: 1.73s
# 380:	learn: 0.2366974	total: 1.06s	remaining: 1.73s
# 381:	learn: 0.2365084	total: 1.07s	remaining: 1.73s
# 382:	learn: 0.2362186	total: 1.07s	remaining: 1.72s
# 383:	learn: 0.2360261	total: 1.07s	remaining: 1.72s
# 384:	learn: 0.2358816	total: 1.07s	remaining: 1.72s
# 385:	learn: 0.2356064	total: 1.08s	remaining: 1.71s
# 386:	learn: 0.2354668	total: 1.08s	remaining: 1.71s
# 387:	learn: 0.2352409	total: 1.08s	remaining: 1.71s
# 388:	learn: 0.2351281	total: 1.08s	remaining: 1.7s
# 389:	learn: 0.2350118	total: 1.09s	remaining: 1.7s
# 390:	learn: 0.2348889	total: 1.09s	remaining: 1.7s
# 391:	learn: 0.2346178	total: 1.09s	remaining: 1.69s
# 392:	learn: 0.2344085	total: 1.09s	remaining: 1.69s
# 393:	learn: 0.2342112	total: 1.1s	remaining: 1.69s
# 394:	learn: 0.2340403	total: 1.1s	remaining: 1.68s
# 395:	learn: 0.2339010	total: 1.1s	remaining: 1.68s
# 396:	learn: 0.2337659	total: 1.1s	remaining: 1.68s
# 397:	learn: 0.2335781	total: 1.11s	remaining: 1.67s
# 398:	learn: 0.2333304	total: 1.11s	remaining: 1.67s
# 399:	learn: 0.2332110	total: 1.11s	remaining: 1.67s
# 400:	learn: 0.2330699	total: 1.11s	remaining: 1.66s
# 401:	learn: 0.2328975	total: 1.12s	remaining: 1.66s
# 402:	learn: 0.2326975	total: 1.12s	remaining: 1.66s
# 403:	learn: 0.2326190	total: 1.12s	remaining: 1.65s
# 404:	learn: 0.2323541	total: 1.12s	remaining: 1.65s
# 405:	learn: 0.2320161	total: 1.13s	remaining: 1.65s
# 406:	learn: 0.2317950	total: 1.13s	remaining: 1.65s
# 407:	learn: 0.2315015	total: 1.13s	remaining: 1.64s
# 408:	learn: 0.2313499	total: 1.13s	remaining: 1.64s
# 409:	learn: 0.2311395	total: 1.14s	remaining: 1.64s
# 410:	learn: 0.2309765	total: 1.14s	remaining: 1.63s
# 411:	learn: 0.2308727	total: 1.14s	remaining: 1.63s
# 412:	learn: 0.2307565	total: 1.15s	remaining: 1.63s
# 413:	learn: 0.2306431	total: 1.15s	remaining: 1.63s
# 414:	learn: 0.2304806	total: 1.15s	remaining: 1.62s
# 415:	learn: 0.2303240	total: 1.15s	remaining: 1.62s
# 416:	learn: 0.2302167	total: 1.16s	remaining: 1.61s
# 417:	learn: 0.2301142	total: 1.16s	remaining: 1.61s
# 418:	learn: 0.2299616	total: 1.16s	remaining: 1.61s
# 419:	learn: 0.2297619	total: 1.16s	remaining: 1.6s
# 420:	learn: 0.2296484	total: 1.17s	remaining: 1.6s
# 421:	learn: 0.2295402	total: 1.17s	remaining: 1.6s
# 422:	learn: 0.2293804	total: 1.17s	remaining: 1.59s
# 423:	learn: 0.2291900	total: 1.17s	remaining: 1.59s
# 424:	learn: 0.2290100	total: 1.18s	remaining: 1.59s
# 425:	learn: 0.2288060	total: 1.18s	remaining: 1.59s
# 426:	learn: 0.2286101	total: 1.18s	remaining: 1.58s
# 427:	learn: 0.2285172	total: 1.18s	remaining: 1.58s
# 428:	learn: 0.2283328	total: 1.19s	remaining: 1.58s
# 429:	learn: 0.2282351	total: 1.19s	remaining: 1.58s
# 430:	learn: 0.2280983	total: 1.19s	remaining: 1.57s
# 431:	learn: 0.2279299	total: 1.2s	remaining: 1.57s
# 432:	learn: 0.2278357	total: 1.2s	remaining: 1.57s
# 433:	learn: 0.2277201	total: 1.2s	remaining: 1.56s
# 434:	learn: 0.2275286	total: 1.2s	remaining: 1.56s
# 435:	learn: 0.2274806	total: 1.21s	remaining: 1.56s
# 436:	learn: 0.2272268	total: 1.21s	remaining: 1.55s
# 437:	learn: 0.2270558	total: 1.21s	remaining: 1.55s
# 438:	learn: 0.2269851	total: 1.21s	remaining: 1.55s
# 439:	learn: 0.2267604	total: 1.22s	remaining: 1.55s
# 440:	learn: 0.2265874	total: 1.22s	remaining: 1.54s
# 441:	learn: 0.2263551	total: 1.22s	remaining: 1.54s
# 442:	learn: 0.2261125	total: 1.22s	remaining: 1.54s
# 443:	learn: 0.2259951	total: 1.23s	remaining: 1.53s
# 444:	learn: 0.2257142	total: 1.23s	remaining: 1.53s
# 445:	learn: 0.2255724	total: 1.23s	remaining: 1.53s
# 446:	learn: 0.2254976	total: 1.23s	remaining: 1.52s
# 447:	learn: 0.2254198	total: 1.24s	remaining: 1.52s
# 448:	learn: 0.2252919	total: 1.24s	remaining: 1.52s
# 449:	learn: 0.2252076	total: 1.24s	remaining: 1.52s
# 450:	learn: 0.2250838	total: 1.24s	remaining: 1.51s
# 451:	learn: 0.2248983	total: 1.25s	remaining: 1.51s
# 452:	learn: 0.2247629	total: 1.25s	remaining: 1.51s
# 453:	learn: 0.2244887	total: 1.25s	remaining: 1.5s
# 454:	learn: 0.2243668	total: 1.25s	remaining: 1.5s
# 455:	learn: 0.2242670	total: 1.26s	remaining: 1.5s
# 456:	learn: 0.2241458	total: 1.26s	remaining: 1.5s
# 457:	learn: 0.2240597	total: 1.26s	remaining: 1.49s
# 458:	learn: 0.2239860	total: 1.26s	remaining: 1.49s
# 459:	learn: 0.2238561	total: 1.27s	remaining: 1.49s
# 460:	learn: 0.2236731	total: 1.27s	remaining: 1.48s
# 461:	learn: 0.2235600	total: 1.27s	remaining: 1.48s
# 462:	learn: 0.2234724	total: 1.27s	remaining: 1.48s
# 463:	learn: 0.2233855	total: 1.28s	remaining: 1.47s
# 464:	learn: 0.2231712	total: 1.28s	remaining: 1.47s
# 465:	learn: 0.2230763	total: 1.28s	remaining: 1.47s
# 466:	learn: 0.2229708	total: 1.28s	remaining: 1.46s
# 467:	learn: 0.2228457	total: 1.29s	remaining: 1.46s
# 468:	learn: 0.2227287	total: 1.29s	remaining: 1.46s
# 469:	learn: 0.2224304	total: 1.29s	remaining: 1.46s
# 470:	learn: 0.2223300	total: 1.3s	remaining: 1.46s
# 471:	learn: 0.2222484	total: 1.3s	remaining: 1.45s
# 472:	learn: 0.2221440	total: 1.3s	remaining: 1.45s
# 473:	learn: 0.2220056	total: 1.3s	remaining: 1.45s
# 474:	learn: 0.2219308	total: 1.31s	remaining: 1.44s
# 475:	learn: 0.2217917	total: 1.31s	remaining: 1.44s
# 476:	learn: 0.2215904	total: 1.31s	remaining: 1.44s
# 477:	learn: 0.2214474	total: 1.31s	remaining: 1.43s
# 478:	learn: 0.2213643	total: 1.32s	remaining: 1.43s
# 479:	learn: 0.2212678	total: 1.32s	remaining: 1.43s
# 480:	learn: 0.2211334	total: 1.32s	remaining: 1.43s
# 481:	learn: 0.2210194	total: 1.32s	remaining: 1.42s
# 482:	learn: 0.2208055	total: 1.33s	remaining: 1.42s
# 483:	learn: 0.2206569	total: 1.33s	remaining: 1.42s
# 484:	learn: 0.2204948	total: 1.33s	remaining: 1.41s
# 485:	learn: 0.2203279	total: 1.33s	remaining: 1.41s
# 486:	learn: 0.2202827	total: 1.34s	remaining: 1.41s
# 487:	learn: 0.2202163	total: 1.34s	remaining: 1.4s
# 488:	learn: 0.2199461	total: 1.34s	remaining: 1.4s
# 489:	learn: 0.2198896	total: 1.34s	remaining: 1.4s
# 490:	learn: 0.2197747	total: 1.35s	remaining: 1.4s
# 491:	learn: 0.2196582	total: 1.35s	remaining: 1.39s
# 492:	learn: 0.2194842	total: 1.35s	remaining: 1.39s
# 493:	learn: 0.2194471	total: 1.35s	remaining: 1.39s
# 494:	learn: 0.2193078	total: 1.36s	remaining: 1.39s
# 495:	learn: 0.2191276	total: 1.36s	remaining: 1.38s
# 496:	learn: 0.2190644	total: 1.36s	remaining: 1.38s
# 497:	learn: 0.2189895	total: 1.36s	remaining: 1.38s
# 498:	learn: 0.2188686	total: 1.37s	remaining: 1.37s
# 499:	learn: 0.2187816	total: 1.37s	remaining: 1.37s
# 500:	learn: 0.2185853	total: 1.37s	remaining: 1.37s
# 501:	learn: 0.2184672	total: 1.38s	remaining: 1.36s
# 502:	learn: 0.2183475	total: 1.38s	remaining: 1.36s
# 503:	learn: 0.2181627	total: 1.38s	remaining: 1.36s
# 504:	learn: 0.2179907	total: 1.38s	remaining: 1.36s
# 505:	learn: 0.2178161	total: 1.39s	remaining: 1.35s
# 506:	learn: 0.2176846	total: 1.39s	remaining: 1.35s
# 507:	learn: 0.2175300	total: 1.39s	remaining: 1.35s
# 508:	learn: 0.2174571	total: 1.39s	remaining: 1.34s
# 509:	learn: 0.2173859	total: 1.4s	remaining: 1.34s
# 510:	learn: 0.2172768	total: 1.4s	remaining: 1.34s
# 511:	learn: 0.2171795	total: 1.4s	remaining: 1.34s
# 512:	learn: 0.2170670	total: 1.41s	remaining: 1.33s
# 513:	learn: 0.2168816	total: 1.41s	remaining: 1.33s
# 514:	learn: 0.2166932	total: 1.41s	remaining: 1.33s
# 515:	learn: 0.2165404	total: 1.41s	remaining: 1.32s
# 516:	learn: 0.2164056	total: 1.42s	remaining: 1.32s
# 517:	learn: 0.2162776	total: 1.42s	remaining: 1.32s
# 518:	learn: 0.2161884	total: 1.42s	remaining: 1.32s
# 519:	learn: 0.2160231	total: 1.42s	remaining: 1.31s
# 520:	learn: 0.2159649	total: 1.43s	remaining: 1.31s
# 521:	learn: 0.2159268	total: 1.43s	remaining: 1.31s
# 522:	learn: 0.2157132	total: 1.43s	remaining: 1.3s
# 523:	learn: 0.2155552	total: 1.43s	remaining: 1.3s
# 524:	learn: 0.2154552	total: 1.44s	remaining: 1.3s
# 525:	learn: 0.2152483	total: 1.44s	remaining: 1.3s
# 526:	learn: 0.2151102	total: 1.44s	remaining: 1.29s
# 527:	learn: 0.2149763	total: 1.44s	remaining: 1.29s
# 528:	learn: 0.2149210	total: 1.45s	remaining: 1.29s
# 529:	learn: 0.2147712	total: 1.45s	remaining: 1.29s
# 530:	learn: 0.2146664	total: 1.45s	remaining: 1.28s
# 531:	learn: 0.2145433	total: 1.46s	remaining: 1.28s
# 532:	learn: 0.2144462	total: 1.46s	remaining: 1.28s
# 533:	learn: 0.2143500	total: 1.46s	remaining: 1.27s
# 534:	learn: 0.2142131	total: 1.46s	remaining: 1.27s
# 535:	learn: 0.2140722	total: 1.47s	remaining: 1.27s
# 536:	learn: 0.2139674	total: 1.47s	remaining: 1.27s
# 537:	learn: 0.2138384	total: 1.47s	remaining: 1.26s
# 538:	learn: 0.2137452	total: 1.47s	remaining: 1.26s
# 539:	learn: 0.2136781	total: 1.48s	remaining: 1.26s
# 540:	learn: 0.2135840	total: 1.48s	remaining: 1.25s
# 541:	learn: 0.2134985	total: 1.48s	remaining: 1.25s
# 542:	learn: 0.2132428	total: 1.48s	remaining: 1.25s
# 543:	learn: 0.2130897	total: 1.49s	remaining: 1.25s
# 544:	learn: 0.2128579	total: 1.49s	remaining: 1.25s
# 545:	learn: 0.2127379	total: 1.49s	remaining: 1.24s
# 546:	learn: 0.2125977	total: 1.5s	remaining: 1.24s
# 547:	learn: 0.2124036	total: 1.5s	remaining: 1.24s
# 548:	learn: 0.2123431	total: 1.5s	remaining: 1.23s
# 549:	learn: 0.2122102	total: 1.5s	remaining: 1.23s
# 550:	learn: 0.2120855	total: 1.51s	remaining: 1.23s
# 551:	learn: 0.2119921	total: 1.51s	remaining: 1.23s
# 552:	learn: 0.2118597	total: 1.51s	remaining: 1.22s
# 553:	learn: 0.2117852	total: 1.51s	remaining: 1.22s
# 554:	learn: 0.2116719	total: 1.52s	remaining: 1.22s
# 555:	learn: 0.2115661	total: 1.52s	remaining: 1.21s
# 556:	learn: 0.2114557	total: 1.52s	remaining: 1.21s
# 557:	learn: 0.2113383	total: 1.52s	remaining: 1.21s
# 558:	learn: 0.2111356	total: 1.53s	remaining: 1.21s
# 559:	learn: 0.2110766	total: 1.53s	remaining: 1.2s
# 560:	learn: 0.2109764	total: 1.53s	remaining: 1.2s
# 561:	learn: 0.2108955	total: 1.54s	remaining: 1.2s
# 562:	learn: 0.2108233	total: 1.54s	remaining: 1.19s
# 563:	learn: 0.2107208	total: 1.54s	remaining: 1.19s
# 564:	learn: 0.2106195	total: 1.55s	remaining: 1.19s
# 565:	learn: 0.2105432	total: 1.55s	remaining: 1.19s
# 566:	learn: 0.2104776	total: 1.55s	remaining: 1.19s
# 567:	learn: 0.2103512	total: 1.55s	remaining: 1.18s
# 568:	learn: 0.2102705	total: 1.56s	remaining: 1.18s
# 569:	learn: 0.2100813	total: 1.56s	remaining: 1.18s
# 570:	learn: 0.2100003	total: 1.56s	remaining: 1.17s
# 571:	learn: 0.2099343	total: 1.56s	remaining: 1.17s
# 572:	learn: 0.2098480	total: 1.57s	remaining: 1.17s
# 573:	learn: 0.2096870	total: 1.57s	remaining: 1.17s
# 574:	learn: 0.2095472	total: 1.57s	remaining: 1.16s
# 575:	learn: 0.2094368	total: 1.57s	remaining: 1.16s
# 576:	learn: 0.2093542	total: 1.58s	remaining: 1.16s
# 577:	learn: 0.2092618	total: 1.58s	remaining: 1.15s
# 578:	learn: 0.2091427	total: 1.58s	remaining: 1.15s
# 579:	learn: 0.2090217	total: 1.59s	remaining: 1.15s
# 580:	learn: 0.2088304	total: 1.59s	remaining: 1.15s
# 581:	learn: 0.2086116	total: 1.59s	remaining: 1.14s
# 582:	learn: 0.2084698	total: 1.59s	remaining: 1.14s
# 583:	learn: 0.2083648	total: 1.59s	remaining: 1.14s
# 584:	learn: 0.2082863	total: 1.6s	remaining: 1.13s
# 585:	learn: 0.2081964	total: 1.6s	remaining: 1.13s
# 586:	learn: 0.2080727	total: 1.6s	remaining: 1.13s
# 587:	learn: 0.2079593	total: 1.6s	remaining: 1.13s
# 588:	learn: 0.2078858	total: 1.61s	remaining: 1.12s
# 589:	learn: 0.2078006	total: 1.61s	remaining: 1.12s
# 590:	learn: 0.2076873	total: 1.61s	remaining: 1.12s
# 591:	learn: 0.2075461	total: 1.61s	remaining: 1.11s
# 592:	learn: 0.2074335	total: 1.62s	remaining: 1.11s
# 593:	learn: 0.2073573	total: 1.62s	remaining: 1.11s
# 594:	learn: 0.2073094	total: 1.62s	remaining: 1.1s
# 595:	learn: 0.2071976	total: 1.63s	remaining: 1.1s
# 596:	learn: 0.2070895	total: 1.63s	remaining: 1.1s
# 597:	learn: 0.2070052	total: 1.63s	remaining: 1.09s
# 598:	learn: 0.2068275	total: 1.63s	remaining: 1.09s
# 599:	learn: 0.2067518	total: 1.64s	remaining: 1.09s
# 600:	learn: 0.2066847	total: 1.64s	remaining: 1.09s
# 601:	learn: 0.2066007	total: 1.64s	remaining: 1.08s
# 602:	learn: 0.2065226	total: 1.64s	remaining: 1.08s
# 603:	learn: 0.2063782	total: 1.64s	remaining: 1.08s
# 604:	learn: 0.2063014	total: 1.65s	remaining: 1.07s
# 605:	learn: 0.2061852	total: 1.65s	remaining: 1.07s
# 606:	learn: 0.2060961	total: 1.65s	remaining: 1.07s
# 607:	learn: 0.2060446	total: 1.66s	remaining: 1.07s
# 608:	learn: 0.2059610	total: 1.66s	remaining: 1.06s
# 609:	learn: 0.2058827	total: 1.66s	remaining: 1.06s
# 610:	learn: 0.2057147	total: 1.66s	remaining: 1.06s
# 611:	learn: 0.2056165	total: 1.67s	remaining: 1.06s
# 612:	learn: 0.2055234	total: 1.67s	remaining: 1.05s
# 613:	learn: 0.2054689	total: 1.67s	remaining: 1.05s
# 614:	learn: 0.2053932	total: 1.67s	remaining: 1.05s
# 615:	learn: 0.2052850	total: 1.68s	remaining: 1.04s
# 616:	learn: 0.2052601	total: 1.68s	remaining: 1.04s
# 617:	learn: 0.2050879	total: 1.68s	remaining: 1.04s
# 618:	learn: 0.2050119	total: 1.68s	remaining: 1.04s
# 619:	learn: 0.2049076	total: 1.69s	remaining: 1.03s
# 620:	learn: 0.2048481	total: 1.69s	remaining: 1.03s
# 621:	learn: 0.2047608	total: 1.69s	remaining: 1.03s
# 622:	learn: 0.2047367	total: 1.69s	remaining: 1.02s
# 623:	learn: 0.2046531	total: 1.7s	remaining: 1.02s
# 624:	learn: 0.2045757	total: 1.7s	remaining: 1.02s
# 625:	learn: 0.2044775	total: 1.7s	remaining: 1.02s
# 626:	learn: 0.2043990	total: 1.7s	remaining: 1.01s
# 627:	learn: 0.2043547	total: 1.71s	remaining: 1.01s
# 628:	learn: 0.2041608	total: 1.71s	remaining: 1.01s
# 629:	learn: 0.2040996	total: 1.71s	remaining: 1s
# 630:	learn: 0.2039659	total: 1.72s	remaining: 1s
# 631:	learn: 0.2038763	total: 1.72s	remaining: 1s
# 632:	learn: 0.2037574	total: 1.72s	remaining: 999ms
# 633:	learn: 0.2036676	total: 1.73s	remaining: 996ms
# 634:	learn: 0.2035672	total: 1.73s	remaining: 993ms
# 635:	learn: 0.2035071	total: 1.73s	remaining: 991ms
# 636:	learn: 0.2034228	total: 1.73s	remaining: 988ms
# 637:	learn: 0.2032592	total: 1.74s	remaining: 985ms
# 638:	learn: 0.2031567	total: 1.74s	remaining: 982ms
# 639:	learn: 0.2030652	total: 1.74s	remaining: 979ms
# 640:	learn: 0.2029800	total: 1.74s	remaining: 976ms
# 641:	learn: 0.2028712	total: 1.75s	remaining: 974ms
# 642:	learn: 0.2027403	total: 1.75s	remaining: 971ms
# 643:	learn: 0.2026477	total: 1.75s	remaining: 968ms
# 644:	learn: 0.2024932	total: 1.75s	remaining: 965ms
# 645:	learn: 0.2023170	total: 1.76s	remaining: 963ms
# 646:	learn: 0.2022764	total: 1.76s	remaining: 960ms
# 647:	learn: 0.2022102	total: 1.76s	remaining: 957ms
# 648:	learn: 0.2021931	total: 1.76s	remaining: 954ms
# 649:	learn: 0.2020880	total: 1.77s	remaining: 952ms
# 650:	learn: 0.2019683	total: 1.77s	remaining: 949ms
# 651:	learn: 0.2018084	total: 1.77s	remaining: 946ms
# 652:	learn: 0.2017188	total: 1.77s	remaining: 943ms
# 653:	learn: 0.2017011	total: 1.78s	remaining: 940ms
# 654:	learn: 0.2016032	total: 1.78s	remaining: 937ms
# 655:	learn: 0.2015880	total: 1.78s	remaining: 934ms
# 656:	learn: 0.2015277	total: 1.78s	remaining: 932ms
# 657:	learn: 0.2013888	total: 1.79s	remaining: 930ms
# 658:	learn: 0.2013313	total: 1.79s	remaining: 927ms
# 659:	learn: 0.2012810	total: 1.79s	remaining: 924ms
# 660:	learn: 0.2012232	total: 1.79s	remaining: 921ms
# 661:	learn: 0.2011056	total: 1.8s	remaining: 918ms
# 662:	learn: 0.2010144	total: 1.8s	remaining: 915ms
# 663:	learn: 0.2009450	total: 1.8s	remaining: 912ms
# 664:	learn: 0.2008731	total: 1.8s	remaining: 910ms
# 665:	learn: 0.2008543	total: 1.81s	remaining: 907ms
# 666:	learn: 0.2007401	total: 1.81s	remaining: 904ms
# 667:	learn: 0.2005931	total: 1.81s	remaining: 901ms
# 668:	learn: 0.2004807	total: 1.81s	remaining: 898ms
# 669:	learn: 0.2004080	total: 1.82s	remaining: 895ms
# 670:	learn: 0.2003254	total: 1.82s	remaining: 893ms
# 671:	learn: 0.2001896	total: 1.82s	remaining: 890ms
# 672:	learn: 0.2000751	total: 1.82s	remaining: 887ms
# 673:	learn: 0.2000171	total: 1.83s	remaining: 884ms
# 674:	learn: 0.1999327	total: 1.83s	remaining: 881ms
# 675:	learn: 0.1998758	total: 1.83s	remaining: 879ms
# 676:	learn: 0.1998136	total: 1.83s	remaining: 876ms
# 677:	learn: 0.1997245	total: 1.84s	remaining: 873ms
# 678:	learn: 0.1996699	total: 1.84s	remaining: 870ms
# 679:	learn: 0.1995338	total: 1.84s	remaining: 867ms
# 680:	learn: 0.1994696	total: 1.84s	remaining: 864ms
# 681:	learn: 0.1994006	total: 1.85s	remaining: 862ms
# 682:	learn: 0.1993412	total: 1.85s	remaining: 859ms
# 683:	learn: 0.1992692	total: 1.85s	remaining: 856ms
# 684:	learn: 0.1992494	total: 1.85s	remaining: 853ms
# 685:	learn: 0.1990832	total: 1.86s	remaining: 850ms
# 686:	learn: 0.1989092	total: 1.86s	remaining: 848ms
# 687:	learn: 0.1988789	total: 1.86s	remaining: 845ms
# 688:	learn: 0.1987196	total: 1.87s	remaining: 842ms
# 689:	learn: 0.1986688	total: 1.87s	remaining: 840ms
# 690:	learn: 0.1985925	total: 1.87s	remaining: 837ms
# 691:	learn: 0.1985374	total: 1.87s	remaining: 834ms
# 692:	learn: 0.1984201	total: 1.88s	remaining: 831ms
# 693:	learn: 0.1983350	total: 1.88s	remaining: 829ms
# 694:	learn: 0.1982648	total: 1.88s	remaining: 826ms
# 695:	learn: 0.1982206	total: 1.88s	remaining: 823ms
# 696:	learn: 0.1981300	total: 1.89s	remaining: 820ms
# 697:	learn: 0.1979847	total: 1.89s	remaining: 818ms
# 698:	learn: 0.1978843	total: 1.89s	remaining: 815ms
# 699:	learn: 0.1977001	total: 1.9s	remaining: 812ms
# 700:	learn: 0.1976244	total: 1.9s	remaining: 810ms
# 701:	learn: 0.1974967	total: 1.9s	remaining: 807ms
# 702:	learn: 0.1974857	total: 1.9s	remaining: 804ms
# 703:	learn: 0.1973435	total: 1.91s	remaining: 803ms
# 704:	learn: 0.1972088	total: 1.91s	remaining: 800ms
# 705:	learn: 0.1971479	total: 1.91s	remaining: 797ms
# 706:	learn: 0.1970064	total: 1.92s	remaining: 795ms
# 707:	learn: 0.1969525	total: 1.92s	remaining: 792ms
# 708:	learn: 0.1967138	total: 1.92s	remaining: 789ms
# 709:	learn: 0.1966683	total: 1.93s	remaining: 786ms
# 710:	learn: 0.1965979	total: 1.93s	remaining: 784ms
# 711:	learn: 0.1965141	total: 1.93s	remaining: 781ms
# 712:	learn: 0.1963841	total: 1.93s	remaining: 778ms
# 713:	learn: 0.1963017	total: 1.94s	remaining: 775ms
# 714:	learn: 0.1962255	total: 1.94s	remaining: 772ms
# 715:	learn: 0.1961246	total: 1.94s	remaining: 770ms
# 716:	learn: 0.1959228	total: 1.94s	remaining: 767ms
# 717:	learn: 0.1957812	total: 1.95s	remaining: 764ms
# 718:	learn: 0.1956892	total: 1.95s	remaining: 761ms
# 719:	learn: 0.1956317	total: 1.95s	remaining: 758ms
# 720:	learn: 0.1955558	total: 1.95s	remaining: 755ms
# 721:	learn: 0.1954660	total: 1.95s	remaining: 753ms
# 722:	learn: 0.1953890	total: 1.96s	remaining: 750ms
# 723:	learn: 0.1953105	total: 1.96s	remaining: 747ms
# 724:	learn: 0.1952513	total: 1.96s	remaining: 744ms
# 725:	learn: 0.1952219	total: 1.97s	remaining: 742ms
# 726:	learn: 0.1951290	total: 1.97s	remaining: 739ms
# 727:	learn: 0.1950774	total: 1.97s	remaining: 737ms
# 728:	learn: 0.1950201	total: 1.97s	remaining: 734ms
# 729:	learn: 0.1949277	total: 1.98s	remaining: 731ms
# 730:	learn: 0.1948592	total: 1.98s	remaining: 728ms
# 731:	learn: 0.1947391	total: 1.98s	remaining: 725ms
# 732:	learn: 0.1946304	total: 1.98s	remaining: 722ms
# 733:	learn: 0.1945098	total: 1.99s	remaining: 720ms
# 734:	learn: 0.1944564	total: 1.99s	remaining: 717ms
# 735:	learn: 0.1942914	total: 1.99s	remaining: 714ms
# 736:	learn: 0.1941810	total: 1.99s	remaining: 711ms
# 737:	learn: 0.1940763	total: 2s	remaining: 708ms
# 738:	learn: 0.1939839	total: 2s	remaining: 706ms
# 739:	learn: 0.1938966	total: 2s	remaining: 703ms
# 740:	learn: 0.1938156	total: 2s	remaining: 700ms
# 741:	learn: 0.1937478	total: 2s	remaining: 697ms
# 742:	learn: 0.1936849	total: 2.01s	remaining: 694ms
# 743:	learn: 0.1936288	total: 2.01s	remaining: 692ms
# 744:	learn: 0.1935883	total: 2.01s	remaining: 689ms
# 745:	learn: 0.1934798	total: 2.01s	remaining: 686ms
# 746:	learn: 0.1933903	total: 2.02s	remaining: 683ms
# 747:	learn: 0.1932596	total: 2.02s	remaining: 681ms
# 748:	learn: 0.1931385	total: 2.02s	remaining: 678ms
# 749:	learn: 0.1930898	total: 2.02s	remaining: 675ms
# 750:	learn: 0.1929744	total: 2.03s	remaining: 673ms
# 751:	learn: 0.1929020	total: 2.03s	remaining: 670ms
# 752:	learn: 0.1928407	total: 2.03s	remaining: 667ms
# 753:	learn: 0.1927853	total: 2.04s	remaining: 664ms
# 754:	learn: 0.1926634	total: 2.04s	remaining: 661ms
# 755:	learn: 0.1926011	total: 2.04s	remaining: 659ms
# 756:	learn: 0.1924969	total: 2.04s	remaining: 656ms
# 757:	learn: 0.1923996	total: 2.04s	remaining: 653ms
# 758:	learn: 0.1922558	total: 2.05s	remaining: 650ms
# 759:	learn: 0.1921665	total: 2.05s	remaining: 648ms
# 760:	learn: 0.1920686	total: 2.05s	remaining: 645ms
# 761:	learn: 0.1919939	total: 2.06s	remaining: 642ms
# 762:	learn: 0.1918688	total: 2.06s	remaining: 639ms
# 763:	learn: 0.1917452	total: 2.06s	remaining: 637ms
# 764:	learn: 0.1917089	total: 2.06s	remaining: 634ms
# 765:	learn: 0.1916367	total: 2.07s	remaining: 631ms
# 766:	learn: 0.1915743	total: 2.07s	remaining: 629ms
# 767:	learn: 0.1915020	total: 2.07s	remaining: 626ms
# 768:	learn: 0.1913918	total: 2.07s	remaining: 623ms
# 769:	learn: 0.1912815	total: 2.08s	remaining: 620ms
# 770:	learn: 0.1911924	total: 2.08s	remaining: 618ms
# 771:	learn: 0.1911632	total: 2.08s	remaining: 615ms
# 772:	learn: 0.1911102	total: 2.08s	remaining: 612ms
# 773:	learn: 0.1909962	total: 2.09s	remaining: 609ms
# 774:	learn: 0.1909308	total: 2.09s	remaining: 607ms
# 775:	learn: 0.1908413	total: 2.09s	remaining: 604ms
# 776:	learn: 0.1907619	total: 2.09s	remaining: 601ms
# 777:	learn: 0.1906915	total: 2.1s	remaining: 598ms
# 778:	learn: 0.1906032	total: 2.1s	remaining: 596ms
# 779:	learn: 0.1905211	total: 2.1s	remaining: 593ms
# 780:	learn: 0.1903785	total: 2.1s	remaining: 590ms
# 781:	learn: 0.1902451	total: 2.11s	remaining: 587ms
# 782:	learn: 0.1902126	total: 2.11s	remaining: 585ms
# 783:	learn: 0.1901190	total: 2.11s	remaining: 582ms
# 784:	learn: 0.1900301	total: 2.11s	remaining: 579ms
# 785:	learn: 0.1899401	total: 2.12s	remaining: 576ms
# 786:	learn: 0.1898628	total: 2.12s	remaining: 574ms
# 787:	learn: 0.1898047	total: 2.12s	remaining: 571ms
# 788:	learn: 0.1897552	total: 2.12s	remaining: 568ms
# 789:	learn: 0.1896802	total: 2.13s	remaining: 565ms
# 790:	learn: 0.1895651	total: 2.13s	remaining: 563ms
# 791:	learn: 0.1894844	total: 2.13s	remaining: 560ms
# 792:	learn: 0.1893440	total: 2.13s	remaining: 557ms
# 793:	learn: 0.1892692	total: 2.14s	remaining: 554ms
# 794:	learn: 0.1891960	total: 2.14s	remaining: 552ms
# 795:	learn: 0.1891437	total: 2.14s	remaining: 549ms
# 796:	learn: 0.1890685	total: 2.15s	remaining: 546ms
# 797:	learn: 0.1889960	total: 2.15s	remaining: 544ms
# 798:	learn: 0.1889537	total: 2.15s	remaining: 541ms
# 799:	learn: 0.1888982	total: 2.15s	remaining: 538ms
# 800:	learn: 0.1888607	total: 2.15s	remaining: 536ms
# 801:	learn: 0.1887793	total: 2.16s	remaining: 533ms
# 802:	learn: 0.1887067	total: 2.16s	remaining: 530ms
# 803:	learn: 0.1886691	total: 2.16s	remaining: 527ms
# 804:	learn: 0.1885782	total: 2.17s	remaining: 525ms
# 805:	learn: 0.1885187	total: 2.17s	remaining: 522ms
# 806:	learn: 0.1884448	total: 2.17s	remaining: 519ms
# 807:	learn: 0.1883536	total: 2.17s	remaining: 516ms
# 808:	learn: 0.1882868	total: 2.17s	remaining: 514ms
# 809:	learn: 0.1881427	total: 2.18s	remaining: 511ms
# 810:	learn: 0.1880589	total: 2.18s	remaining: 508ms
# 811:	learn: 0.1879770	total: 2.18s	remaining: 505ms
# 812:	learn: 0.1878895	total: 2.19s	remaining: 503ms
# 813:	learn: 0.1877824	total: 2.19s	remaining: 500ms
# 814:	learn: 0.1877383	total: 2.19s	remaining: 497ms
# 815:	learn: 0.1876988	total: 2.19s	remaining: 495ms
# 816:	learn: 0.1875876	total: 2.19s	remaining: 492ms
# 817:	learn: 0.1875556	total: 2.2s	remaining: 489ms
# 818:	learn: 0.1875031	total: 2.2s	remaining: 486ms
# 819:	learn: 0.1874470	total: 2.2s	remaining: 483ms
# 820:	learn: 0.1874035	total: 2.2s	remaining: 481ms
# 821:	learn: 0.1873248	total: 2.21s	remaining: 478ms
# 822:	learn: 0.1872252	total: 2.21s	remaining: 475ms
# 823:	learn: 0.1871539	total: 2.21s	remaining: 472ms
# 824:	learn: 0.1870918	total: 2.21s	remaining: 470ms
# 825:	learn: 0.1870194	total: 2.22s	remaining: 467ms
# 826:	learn: 0.1868949	total: 2.22s	remaining: 464ms
# 827:	learn: 0.1867559	total: 2.22s	remaining: 462ms
# 828:	learn: 0.1867176	total: 2.22s	remaining: 459ms
# 829:	learn: 0.1865947	total: 2.23s	remaining: 456ms
# 830:	learn: 0.1865255	total: 2.23s	remaining: 453ms
# 831:	learn: 0.1864899	total: 2.23s	remaining: 451ms
# 832:	learn: 0.1864092	total: 2.23s	remaining: 448ms
# 833:	learn: 0.1863106	total: 2.24s	remaining: 445ms
# 834:	learn: 0.1862937	total: 2.24s	remaining: 442ms
# 835:	learn: 0.1861335	total: 2.24s	remaining: 440ms
# 836:	learn: 0.1860636	total: 2.25s	remaining: 437ms
# 837:	learn: 0.1859778	total: 2.25s	remaining: 435ms
# 838:	learn: 0.1859228	total: 2.25s	remaining: 432ms
# 839:	learn: 0.1858064	total: 2.25s	remaining: 429ms
# 840:	learn: 0.1857046	total: 2.25s	remaining: 426ms
# 841:	learn: 0.1856626	total: 2.26s	remaining: 424ms
# 842:	learn: 0.1855864	total: 2.26s	remaining: 421ms
# 843:	learn: 0.1855029	total: 2.26s	remaining: 418ms
# 844:	learn: 0.1854150	total: 2.27s	remaining: 416ms
# 845:	learn: 0.1853938	total: 2.27s	remaining: 413ms
# 846:	learn: 0.1853453	total: 2.27s	remaining: 410ms
# 847:	learn: 0.1851787	total: 2.27s	remaining: 408ms
# 848:	learn: 0.1850112	total: 2.28s	remaining: 405ms
# 849:	learn: 0.1850003	total: 2.28s	remaining: 402ms
# 850:	learn: 0.1849502	total: 2.28s	remaining: 400ms
# 851:	learn: 0.1848467	total: 2.29s	remaining: 397ms
# 852:	learn: 0.1847479	total: 2.29s	remaining: 394ms
# 853:	learn: 0.1846708	total: 2.29s	remaining: 392ms
# 854:	learn: 0.1846042	total: 2.29s	remaining: 389ms
# 855:	learn: 0.1845617	total: 2.29s	remaining: 386ms
# 856:	learn: 0.1844776	total: 2.3s	remaining: 383ms
# 857:	learn: 0.1843890	total: 2.3s	remaining: 381ms
# 858:	learn: 0.1843358	total: 2.3s	remaining: 378ms
# 859:	learn: 0.1842766	total: 2.3s	remaining: 375ms
# 860:	learn: 0.1842089	total: 2.31s	remaining: 373ms
# 861:	learn: 0.1841304	total: 2.31s	remaining: 370ms
# 862:	learn: 0.1840900	total: 2.31s	remaining: 367ms
# 863:	learn: 0.1839093	total: 2.32s	remaining: 365ms
# 864:	learn: 0.1838718	total: 2.32s	remaining: 362ms
# 865:	learn: 0.1837918	total: 2.32s	remaining: 359ms
# 866:	learn: 0.1837420	total: 2.32s	remaining: 356ms
# 867:	learn: 0.1836809	total: 2.33s	remaining: 354ms
# 868:	learn: 0.1836167	total: 2.33s	remaining: 351ms
# 869:	learn: 0.1835031	total: 2.33s	remaining: 348ms
# 870:	learn: 0.1834432	total: 2.33s	remaining: 346ms
# 871:	learn: 0.1833888	total: 2.34s	remaining: 343ms
# 872:	learn: 0.1833515	total: 2.34s	remaining: 340ms
# 873:	learn: 0.1833029	total: 2.34s	remaining: 338ms
# 874:	learn: 0.1832590	total: 2.34s	remaining: 335ms
# 875:	learn: 0.1831814	total: 2.35s	remaining: 332ms
# 876:	learn: 0.1830410	total: 2.35s	remaining: 329ms
# 877:	learn: 0.1829397	total: 2.35s	remaining: 327ms
# 878:	learn: 0.1828374	total: 2.35s	remaining: 324ms
# 879:	learn: 0.1827800	total: 2.35s	remaining: 321ms
# 880:	learn: 0.1827280	total: 2.36s	remaining: 319ms
# 881:	learn: 0.1826745	total: 2.36s	remaining: 316ms
# 882:	learn: 0.1826119	total: 2.36s	remaining: 313ms
# 883:	learn: 0.1824979	total: 2.37s	remaining: 310ms
# 884:	learn: 0.1824199	total: 2.37s	remaining: 308ms
# 885:	learn: 0.1823895	total: 2.37s	remaining: 305ms
# 886:	learn: 0.1823256	total: 2.37s	remaining: 302ms
# 887:	learn: 0.1822467	total: 2.38s	remaining: 300ms
# 888:	learn: 0.1821953	total: 2.38s	remaining: 297ms
# 889:	learn: 0.1821029	total: 2.38s	remaining: 294ms
# 890:	learn: 0.1820371	total: 2.38s	remaining: 292ms
# 891:	learn: 0.1819761	total: 2.39s	remaining: 289ms
# 892:	learn: 0.1819397	total: 2.39s	remaining: 286ms
# 893:	learn: 0.1818556	total: 2.39s	remaining: 284ms
# 894:	learn: 0.1818005	total: 2.39s	remaining: 281ms
# 895:	learn: 0.1817304	total: 2.4s	remaining: 278ms
# 896:	learn: 0.1816338	total: 2.4s	remaining: 276ms
# 897:	learn: 0.1815212	total: 2.4s	remaining: 273ms
# 898:	learn: 0.1814843	total: 2.4s	remaining: 270ms
# 899:	learn: 0.1814601	total: 2.41s	remaining: 267ms
# 900:	learn: 0.1813999	total: 2.41s	remaining: 265ms
# 901:	learn: 0.1812899	total: 2.41s	remaining: 262ms
# 902:	learn: 0.1811461	total: 2.42s	remaining: 260ms
# 903:	learn: 0.1811013	total: 2.42s	remaining: 257ms
# 904:	learn: 0.1810764	total: 2.42s	remaining: 254ms
# 905:	learn: 0.1809945	total: 2.42s	remaining: 252ms
# 906:	learn: 0.1809554	total: 2.43s	remaining: 249ms
# 907:	learn: 0.1808840	total: 2.43s	remaining: 246ms
# 908:	learn: 0.1807907	total: 2.43s	remaining: 244ms
# 909:	learn: 0.1807556	total: 2.44s	remaining: 241ms
# 910:	learn: 0.1806665	total: 2.44s	remaining: 239ms
# 911:	learn: 0.1805513	total: 2.44s	remaining: 236ms
# 912:	learn: 0.1804997	total: 2.45s	remaining: 233ms
# 913:	learn: 0.1804528	total: 2.45s	remaining: 231ms
# 914:	learn: 0.1803971	total: 2.45s	remaining: 228ms
# 915:	learn: 0.1803442	total: 2.45s	remaining: 225ms
# 916:	learn: 0.1802898	total: 2.46s	remaining: 222ms
# 917:	learn: 0.1801775	total: 2.46s	remaining: 220ms
# 918:	learn: 0.1801363	total: 2.46s	remaining: 217ms
# 919:	learn: 0.1800471	total: 2.46s	remaining: 214ms
# 920:	learn: 0.1799613	total: 2.47s	remaining: 212ms
# 921:	learn: 0.1799158	total: 2.47s	remaining: 209ms
# 922:	learn: 0.1798471	total: 2.47s	remaining: 206ms
# 923:	learn: 0.1797780	total: 2.48s	remaining: 204ms
# 924:	learn: 0.1797197	total: 2.48s	remaining: 201ms
# 925:	learn: 0.1796633	total: 2.48s	remaining: 198ms
# 926:	learn: 0.1795867	total: 2.48s	remaining: 196ms
# 927:	learn: 0.1795094	total: 2.48s	remaining: 193ms
# 928:	learn: 0.1794805	total: 2.49s	remaining: 190ms
# 929:	learn: 0.1793957	total: 2.49s	remaining: 187ms
# 930:	learn: 0.1793389	total: 2.49s	remaining: 185ms
# 931:	learn: 0.1792896	total: 2.5s	remaining: 182ms
# 932:	learn: 0.1792583	total: 2.5s	remaining: 179ms
# 933:	learn: 0.1791816	total: 2.5s	remaining: 177ms
# 934:	learn: 0.1791163	total: 2.5s	remaining: 174ms
# 935:	learn: 0.1790871	total: 2.5s	remaining: 171ms
# 936:	learn: 0.1790230	total: 2.51s	remaining: 169ms
# 937:	learn: 0.1789866	total: 2.51s	remaining: 166ms
# 938:	learn: 0.1789271	total: 2.51s	remaining: 163ms
# 939:	learn: 0.1788703	total: 2.51s	remaining: 161ms
# 940:	learn: 0.1787906	total: 2.52s	remaining: 158ms
# 941:	learn: 0.1787217	total: 2.52s	remaining: 155ms
# 942:	learn: 0.1785073	total: 2.52s	remaining: 152ms
# 943:	learn: 0.1784469	total: 2.52s	remaining: 150ms
# 944:	learn: 0.1783517	total: 2.53s	remaining: 147ms
# 945:	learn: 0.1783181	total: 2.53s	remaining: 144ms
# 946:	learn: 0.1782714	total: 2.53s	remaining: 142ms
# 947:	learn: 0.1782468	total: 2.53s	remaining: 139ms
# 948:	learn: 0.1781492	total: 2.54s	remaining: 136ms
# 949:	learn: 0.1780979	total: 2.54s	remaining: 134ms
# 950:	learn: 0.1780140	total: 2.54s	remaining: 131ms
# 951:	learn: 0.1779030	total: 2.54s	remaining: 128ms
# 952:	learn: 0.1778719	total: 2.55s	remaining: 126ms
# 953:	learn: 0.1777811	total: 2.55s	remaining: 123ms
# 954:	learn: 0.1776935	total: 2.55s	remaining: 120ms
# 955:	learn: 0.1776103	total: 2.56s	remaining: 118ms
# 956:	learn: 0.1775661	total: 2.56s	remaining: 115ms
# 957:	learn: 0.1774960	total: 2.56s	remaining: 112ms
# 958:	learn: 0.1774170	total: 2.56s	remaining: 110ms
# 959:	learn: 0.1773847	total: 2.56s	remaining: 107ms
# 960:	learn: 0.1773087	total: 2.57s	remaining: 104ms
# 961:	learn: 0.1772316	total: 2.57s	remaining: 102ms
# 962:	learn: 0.1771970	total: 2.57s	remaining: 98.9ms
# 963:	learn: 0.1771045	total: 2.58s	remaining: 96.2ms
# 964:	learn: 0.1770833	total: 2.58s	remaining: 93.5ms
# 965:	learn: 0.1770326	total: 2.58s	remaining: 90.9ms
# 966:	learn: 0.1769269	total: 2.58s	remaining: 88.2ms
# 967:	learn: 0.1768437	total: 2.59s	remaining: 85.5ms
# 968:	learn: 0.1768106	total: 2.59s	remaining: 82.8ms
# 969:	learn: 0.1767335	total: 2.59s	remaining: 80.1ms
# 970:	learn: 0.1766578	total: 2.59s	remaining: 77.5ms
# 971:	learn: 0.1766188	total: 2.6s	remaining: 74.8ms
# 972:	learn: 0.1765733	total: 2.6s	remaining: 72.1ms
# 973:	learn: 0.1765276	total: 2.6s	remaining: 69.5ms
# 974:	learn: 0.1764565	total: 2.6s	remaining: 66.8ms
# 975:	learn: 0.1764029	total: 2.61s	remaining: 64.1ms
# 976:	learn: 0.1763417	total: 2.61s	remaining: 61.4ms
# 977:	learn: 0.1762789	total: 2.61s	remaining: 58.8ms
# 978:	learn: 0.1761961	total: 2.61s	remaining: 56.1ms
# 979:	learn: 0.1761394	total: 2.62s	remaining: 53.4ms
# 980:	learn: 0.1760865	total: 2.62s	remaining: 50.7ms
# 981:	learn: 0.1760236	total: 2.62s	remaining: 48.1ms
# 982:	learn: 0.1759820	total: 2.63s	remaining: 45.4ms
# 983:	learn: 0.1759411	total: 2.63s	remaining: 42.7ms
# 984:	learn: 0.1758693	total: 2.63s	remaining: 40.1ms
# 985:	learn: 0.1758348	total: 2.63s	remaining: 37.4ms
# 986:	learn: 0.1757719	total: 2.63s	remaining: 34.7ms
# 987:	learn: 0.1756884	total: 2.64s	remaining: 32ms
# 988:	learn: 0.1756273	total: 2.64s	remaining: 29.4ms
# 989:	learn: 0.1755643	total: 2.64s	remaining: 26.7ms
# 990:	learn: 0.1754975	total: 2.65s	remaining: 24ms
# 991:	learn: 0.1754329	total: 2.65s	remaining: 21.4ms
# 992:	learn: 0.1753609	total: 2.65s	remaining: 18.7ms
# 993:	learn: 0.1752743	total: 2.65s	remaining: 16ms
# 994:	learn: 0.1752218	total: 2.66s	remaining: 13.3ms
# 995:	learn: 0.1751552	total: 2.66s	remaining: 10.7ms
# 996:	learn: 0.1750802	total: 2.66s	remaining: 8.01ms
# 997:	learn: 0.1749915	total: 2.66s	remaining: 5.34ms
# 998:	learn: 0.1749495	total: 2.67s	remaining: 2.67ms
# 999:	learn: 0.1748860	total: 2.67s	remaining: 0us

# %%
sample_sub[target] = preds
sample_sub.to_csv(data_path + 'sub1.csv', index = False)

# %% [markdown]
# ---
# # Cross Validation

# %%
# Cross Validation for Boosting
def cross_val(regressor, train, test, features, name):
    N_splits = 7
    
    oofs = np.zeros(len(train))
    preds = np.zeros(len(test))
    
    target_col = train[target]
    
    folds = StratifiedKFold(n_splits = N_splits, shuffle = True,random_state = 1999)
    stratified_target = pd.qcut( train[target], 10, labels=False, duplicates='drop')
    for index, (trn_idx, val_idx) in enumerate(folds.split(train, stratified_target)):
        print(f'\n================================Fold{index + 1}===================================')
        
        #### Train Set
        X_trn, y_trn = train[features].iloc[trn_idx], train[target].iloc[trn_idx]
        
        #### Validation Set
        X_val, y_val = train[features].iloc[val_idx], train[target].iloc[val_idx]
        
        #### Test Set
        X_test = test[features]
        
        if name != 'cat':
            #### Scaling Data ####
            scaler = StandardScaler()
            _ = scaler.fit(X_trn)
            X_trn = scaler.transform(X_trn)
            X_val = scaler.transform(X_val)
            X_test = scaler.transform(X_test)
        
        ############ Fitting #############
        _ = regressor.fit(X_trn, y_trn, eval_set = [(X_val, y_val)], early_stopping_rounds = 100, verbose = False)
        
        ############ Predicting #############
        val_preds = np.abs(regressor.predict(X_val))
        test_preds = np.abs(regressor.predict(X_test))
        
        error = 100*max(0, 1-mean_squared_error(y_val, val_preds))
        print(f'\n Score for Validation set is : {error}')
        
        oofs[val_idx] = val_preds
        preds += test_preds / N_splits
        
    total_error = 100*max(0, 1-mean_squared_error(y_val, val_preds))
    print(f'\n\Score for oofs is {total_error}')
    
    return oofs, preds

# %%
# Cross Validation for Boosting
def normal_cross_val(regressor, train, test, features, name):
    N_splits = 7
    
    oofs = np.zeros(len(train))
    preds = np.zeros(len(test))
    
    target_col = train[target]
    
    folds = StratifiedKFold(n_splits = N_splits, shuffle = True,random_state = 1999)
    stratified_target = pd.qcut( train[target], 10, labels=False, duplicates='drop')
    for index, (trn_idx, val_idx) in enumerate(folds.split(train, stratified_target)):
        print(f'\n================================Fold{index + 1}===================================')
        
        #### Train Set
        X_trn, y_trn = train[features].iloc[trn_idx], train[target].iloc[trn_idx]
        
        #### Validation Set
        X_val, y_val = train[features].iloc[val_idx], train[target].iloc[val_idx]
        
        #### Test Set
        X_test = test[features]
        
        if name != 'cat':
            #### Scaling Data ####
            scaler = StandardScaler()
            _ = scaler.fit(X_trn)
            X_trn = scaler.transform(X_trn)
            X_val = scaler.transform(X_val)
            X_test = scaler.transform(X_test)
        
        ############ Fitting #############
        _ = regressor.fit(X_trn, y_trn)
        
        ############ Predicting #############
        val_preds = np.abs(regressor.predict(X_val))
        test_preds = np.abs(regressor.predict(X_test))
        
        error = 100*max(0, 1-mean_squared_error(y_val, val_preds))
        print(f'\n Score for Validation set is : {error}')
        
        oofs[val_idx] = val_preds
        preds += test_preds / N_splits
        
    total_error = 100*max(0, 1-mean_squared_error(y_val, val_preds))
    print(f'\n\Score for oofs is {total_error}')
    
    return oofs, preds

# %%
params = {'depth': 5, 'n_estimators': 1694, 'learning_rate': 0.08193293802306104}
cat = CatBoostRegressor(random_state = 1, **params)

# %%
# %%time
cat_oofs, cat_preds = cross_val(cat, train_proc, test_proc, features, 'cat')
# Out:
# ================================Fold1===================================
#
#  Score for Validation set is : 91.58707868816231
#
# ================================Fold2===================================
#
#  Score for Validation set is : 91.54318960757261
#
# ================================Fold3===================================
#
#  Score for Validation set is : 92.40515925833174
#
# ================================Fold4===================================
#
#  Score for Validation set is : 91.31435822954025
#
# ================================Fold5===================================
#
#  Score for Validation set is : 89.98334430516542
#
# ================================Fold6===================================
#
#  Score for Validation set is : 90.20700369898572
#
# ================================Fold7===================================
#
#  Score for Validation set is : 91.28358294389555
#
# ================================Fold8===================================
#
#  Score for Validation set is : 90.26720573096728
#
# ================================Fold9===================================
#
#  Score for Validation set is : 93.19030935850535
#
# ================================Fold10===================================
#
#  Score for Validation set is : 94.36956864717492
#
# \Score for oofs is 94.36956864717492
# Wall time: 29.8 s

# %%
sample_sub[target] = np.exp(cat_preds)
sample_sub.to_csv(data_path + 'sub1.csv', index = False)

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# import optuna
# from sklearn.metrics import *
# from sklearn.model_selection import KFold
# from catboost import CatBoostRegressor
# from xgboost import XGBRegressor
# import numpy as np
#
#
# def objective(trial):
#   param = {
#       "max_depth": trial.suggest_int("max_depth", 3, 20),
#       "n_estimators": trial.suggest_int("n_estimators", 500, 1500),
#       "learning_rate": trial.suggest_float("learning_rate", 0.01, 1),
#       "num_leaves" : trial.suggest_int("num_leaves", 40, 500)
#       #"l2_leaf_reg": trial.suggest_float("l2_leaf_reg", 1, 3),
#       #"subsample": trial.suggest_float("subsample", 0.1, 1),
#       #'colsample_bylevel': trial.suggest_float('colsample_bylevel,', 0.1, 1),
#       #'random_strength':trial.suggest_int('random_strength', 0, 1)
#   }
#
#   skf = KFold(n_splits = 5, shuffle=True, random_state=42)
#
#   for fold, (tr_ind, val_ind) in enumerate(skf.split(train_proc[features], train_proc[target])):
#
#     X_train, X_val     = train_proc[features].loc[tr_ind], train_proc[features].loc[val_ind]
#     y_train, y_val     = train_proc[target][tr_ind], train_proc[target][val_ind]
#
#     model              = LGBMRegressor(**param, random_state=42)
#
#     model.fit(X_train, y_train)
#
#     val_pred           = np.abs(model.predict(X_val))
#     accuracy           = 100 * max(0, 1-mean_squared_error(y_val, val_pred))
#
#   return accuracy
#
# study = optuna.create_study(direction="maximize")
# study.optimize(objective, n_trials=300)

# %% [markdown]
# # Feature Engineering

# %%
def join(train_, test_):
    df = pd.concat([train_, test_], axis = 0).reset_index(drop=True)
    
    return df

def split(df_):
    train_, test_ = df_[:train.shape[0]], df[train.shape[0]:].reset_index(drop=True)
    features_ = [col for col in df_.columns if col not in ([ID, name, date_1, date_2, location, target])]
    
    return train_, test_, features_

# %%
df = join(train_proc, test_proc)

# %% [markdown]
# df['location'] = df['Customer Location'].apply(lambda x: x.split(',')[0])
# df['Country'] = df['Customer Location'].apply(lambda x: len(x.split(',')))
#
# space_country_index = df[ df['Country'] == 1].index
# comma_country_index = df[ df['Country'] == 2].index
# df.loc[space_country_index, 'location'] = df.iloc[space_country_index]['Customer Location'].apply(lambda x: x.split()[0])
#
# ########### Extracting Country
#
# df.loc[space_country_index, 'Country'] = df.iloc[space_country_index]['Customer Location'].apply(lambda x: x.split()[1])
# df.loc[comma_country_index, 'Country'] = df.iloc[comma_country_index]['Customer Location'].apply(lambda x: x.split(',')[1].split()[0])

# %% [markdown]
# df[['location', 'Country']] = df[['location', 'Country']].apply(le.fit_transform)

# %% [markdown]
# ## Datetime Features

# %%
df['Delivery Date'] = pd.to_datetime(df['Delivery Date'])
df['Scheduled Date'] = pd.to_datetime(df['Scheduled Date'])

# %%
df['Date_Diff'] = (df['Delivery Date'] - df['Scheduled Date']).dt.days

# %%
train_feat, test_feat, feats = split(df)

# %% [markdown]
# **Artist reputation**

# %%
bin_names = [i for i in range(0, 10)]


#df['Height_bins'] = np.array(np.floor(np.array(df['Height']) / 10.))
df['Width_bins'] = np.array(np.floor(np.array(df['Width']) / 10.))
df['price_bins'] = np.array(np.floor(np.array(df['Price Of Sculpture']) / 10))
#df['shipping'] = np.array(np.floor(np.array(df['Base Shipping Price']) / 10.))

#df['weight_bins'] = np.array(np.floor(np.array(df['Weight']) / 1000.)) 
#df['artist_bins'] = np.array(np.floor(np.array(df['Artist Reputation']) / 0.1))

# %%
#df['cost_per_height_material'] = df.groupby(['Material', 'Height_bins', 'Width_bins', 'price_bins'])['Cost'].transform('median')
#df['cost_per_height_material_mean'] = df.groupby(['Material', 'Height_bins', 'Width_bins', 'price_bins'])['Cost'].transform('mean')
#df['cost_per_height_material_max'] = df.groupby(['Material', 'Height_bins', 'Width_bins', 'price_bins'])['Cost'].transform('max')
#df['cost_per_height_material_min'] = df.groupby(['Material', 'Height_bins', 'Width_bins', 'price_bins'])['Cost'].transform('min')

# %%
# train_price_bins = list(df.loc[[i for i in range(0, 6500)]]['price_bins'].unique())

# def imputer(x, col):
#     return df[ df['price_bins'] == x][col].median()

# def imputer_2(x, col):
#     nearest = train_price_bins[min(range(len(train_price_bins)), key = lambda i: abs(train_price_bins[i]-x))]
#     return imputer(nearest, col)

# %%
#df.loc[ df['cost_per_height_material'].isna(), 'cost_per_height_material'] = df[ df['cost_per_height_material'].isna()]['price_bins'].apply(lambda x: imputer_2(x, 'cost_per_height_material'))
#df.loc[ df['cost_per_height_material_mean'].isna(), 'cost_per_height_material_mean'] = df[ df['cost_per_height_material_mean'].isna()]['price_bins'].apply(lambda x: imputer_2(x, 'cost_per_height_material_mean'))
#df.loc[ df['cost_per_height_material_max'].isna(), 'cost_per_height_material_max'] = df[ df['cost_per_height_material_max'].isna()]['price_bins'].apply(lambda x: imputer_2(x, 'cost_per_height_material_max'))
#df.loc[ df['cost_per_height_material_min'].isna(), 'cost_per_height_material_min'] = df[ df['cost_per_height_material_min'].isna()]['price_bins'].apply(lambda x: imputer_2(x, 'cost_per_height_material_min'))

# %% [markdown]
# ---

# %% [markdown]
# # Arithmatic Features

# %%
#df['median_shipping_price_per_transport'] = df.groupby(['Material'])['Base Shipping Price'].transform('median')
#df['median_shipping_price_per_transport'] = df['median_shipping_price_per_transport']*df['Weight']

# %%
df['Weight_/_Shipping'] = df['Weight'] / df['Base Shipping Price']
#df['Height_Width_/_Shipping'] = (df['Height'] * df['Width']) / df['Base Shipping Price']

# %% [markdown]
# ### Shipping price --->>>

# %%
df['median_shipping_per_material_transport'] = df.groupby(['Material'])['Base Shipping Price'].transform('median')
#df['median_shipping_per_material_price'] = df.groupby(['Material'])['Price Of Sculpture'].transform('median')

# %% [markdown]
# # Volume

# %%
df['volume'] = (df['Height']**2) * (df['Width'])

# %%
train_feat, test_feat, feats = split(df)

# %%
lgb_oofs, lgb_preds = cross_val(cat, train_feat, test_feat, feats, 'cat')
# Out:
# ================================Fold1===================================
#
#  Score for Validation set is : 94.08212978782433
#
# ================================Fold2===================================
#
#  Score for Validation set is : 93.80547969463147
#
# ================================Fold3===================================
#
#  Score for Validation set is : 94.12854489053215
#
# ================================Fold4===================================
#
#  Score for Validation set is : 92.00280674062637
#
# ================================Fold5===================================
#
#  Score for Validation set is : 93.00385178082983
#
# ================================Fold6===================================
#
#  Score for Validation set is : 92.84839199249822
#
# ================================Fold7===================================
#
#  Score for Validation set is : 94.15596592832615
#
# \Score for oofs is 94.15596592832615

# %%
sample_sub[target] = np.exp(lgb_preds)
sample_sub.to_csv(data_path + 'sub1.csv', index = False)
